# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np

# %%
with open('PI_H.pkl', 'rb') as f:
    dct_fitness = pickle.load(f)

# %%
t1 = dct_fitness['CEC_44']
t2 = dct_fitness['CEC_47']

# %%
plt.plot(np.log(np.array(t1[::50])), linestyle='dashdot')
